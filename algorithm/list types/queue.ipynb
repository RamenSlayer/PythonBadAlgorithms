# %% [raw]
# push n
# Добавить в очередь число n (значение n задается после команды). Программа должна вывести ok.
#
# pop
# Удалить из очереди первый элемент. Программа должна вывести его значение.
#
# front
# Программа должна вывести значение первого элемента, не удаляя его из очереди.
#
# size
# Программа должна вывести количество элементов в очереди.
#
# clear
# Программа должна очистить очередь и вывести ok.
#
# exit
# Программа должна вывести bye и завершить работу.

# %%
class Queue():
    def __init__(self):
        self.queue = [0, 0, 0]
        self.left = -1
        self.right = 0
        self.length = 3
        self.size = 0

    def push(self, n):
        if self.size < self.length:
            if self.right >= self.length:
                self.right -= self.length
            self.queue[self.right] = n
            self.right += 1
            if self.right > self.length:
                self.right -= self.size
            self.size += 1
        else:
            self.queue.insert(self.right, n)
            self.size += 1
            self.length += 1
            self.left += 1 * int(self.left != -1)
            self.right += 1
        print('ok')
#         print(self.queue)

    def pop(self):
        if self.size == 0:
            print('error')
            return
        print(self.queue[(self.left + 1) * (self.left < (self.length - 1))])
        self.queue[(self.left + 1) * (self.left < (self.length - 1))] = 0
        self.size -= 1
        self.left += 1
        if self.left >= self.length:
            self.left -= self.length
#         print(self.queue)

    def front(self):
        if self.size < 1:
            print("error")
            return
        print(self.queue[(self.left + 1) * (self.left < (self.length - 1))])
#         print(self.left)

    def Size(self):
        print(self.size)

    def clear(self):
        self.queue = [0, 0, 0]
        self.left = -1
        self.right = 0
        self.length = 3
        self.size = 0
        print('ok')

# %%
q = Queue()

while True:
    inp = input().split()
    cmd = inp[0]
    if cmd == "push":
        q.push(inp[1])
    elif cmd == "pop":
        q.pop()
    elif cmd == "front":
        q.front()
    elif cmd == "size":
        q.Size()
    elif cmd == "clear":
        q.clear()
    elif cmd == "exit":
        print('bye')
        break
# Out:
# exit
# bye

# %%
class Queue():
    def __init__(self):
        self.queue = [0, 0, 0]
        self.left = -1
        self.right = 0
        self.length = 3
        self.Size = 0

    def push(self, n):
        if self.Size < self.length:
            if self.right >= self.length:
                self.right -= self.length
            self.queue[self.right] = n
            self.right += 1
            if self.right > self.length:
                self.right -= self.Size
            self.Size += 1
        else:
            self.queue.insert(self.right, n)
            self.Size += 1
            self.length += 1
            self.left += 1 * int(self.left != -1)
            self.right += 1

    def pop(self):
        if self.size == 0:
            print('error')
            return
        tmp = self.queue[(self.left + 1) * (self.left < (self.length - 1))]
        self.queue[(self.left + 1) * (self.left < (self.length - 1))] = None
        self.Size -= 1
        self.left += 1
        if self.left >= self.length:
            self.left -= self.length
        return tmp

    def front(self):
        if self.Size < 1:
            print("error")
            return
        return self.queue[(self.left + 1) * (self.left < (self.length - 1))]

    def size(self):
        return self.Size

    def clear(self):
        self.queue = [0, 0, 0]
        self.left = -1
        self.right = 0
        self.length = 3
        self.Size = 0
        return
    
    def __str__(self):
        return str(self.queue)

# %%
f = Queue()
# tmp = list(map(int, input().split()))
tmp = [1,7,3,9,4]
for i in tmp:
    t = i
    f.push(t)
# print(f)
s = Queue()
# tmp = list(map(int, input().split()))
tmp = [5,8,0,2,6]
for i in tmp:
    t = i
    s.push(t)
# print(s)

# %%
f = list(map(int, input().split()))
s = list(map(int, input().split()))
# Out:
# 1 3 5 7 9
# 2 4 6 8 0

# %%
cnt = 0
while (cnt < 10**6) and (len(f) != 0) and (len(s) != 0):
#     print()
#     print(cnt)
    if f[0] > s[0]:
        if f[0] == 9 and s[0] == 0:
            s.append(f.pop(0))
            s.append(s.pop(0))
        else:
            f.append(f.pop(0))
            f.append(s.pop(0))
    else:
        if s[0] == 9 and f[0] == 0:
            f.append(f.pop(0))
            f.append(s.pop(0))
        else:
            s.append(f.pop(0))
            s.append(s.pop(0))
    cnt += 1

# print('Winner:')
if len(f) == 0:
    print("second", cnt)
elif len(s) == 0:
    print("first", cnt)
else:
    print("botva")
# Out:
# second 5

# %%
f = list(map(int, input().split()))
s = list(map(int, input().split()))

cnt = 0
while (cnt < 10**6) and (len(f) != 0) and (len(s) != 0):
    if f[0] > s[0]:
        if f[0] == 9 and s[0] == 0:
            s.append(f.pop(0))
            s.append(s.pop(0))
        else:
            f.append(f.pop(0))
            f.append(s.pop(0))
    else:
        if s[0] == 9 and f[0] == 0:
            f.append(f.pop(0))
            f.append(s.pop(0))
        else:
            s.append(f.pop(0))
            s.append(s.pop(0))
    cnt += 1

if len(f) == 0:
    print("second", cnt)
elif len(s) == 0:
    print("first", cnt)
else:
    print("botva")
